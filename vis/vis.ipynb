# %% [markdown]
# # Visualization: Light-weight-MPC

# %%
from SimulationData import *
from plot_func import PlotPrediction, PlotInput
from matplotlib import pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## List simulations avaliable

# %%
SIMULATIONS_FILEPATH = "/data/simulations"
ListSimulations(SIMULATIONS_FILEPATH)
# Out:
# /data/simulations/sim_siso_test.json
# /data/simulations/sim_1.json
# /data/simulations/test_sim.json
# /data/simulations/sim_SingleWell.json
# /data/simulations/sim_2.json
# /data/simulations/sim_3.json
# /data/simulations/sim_open_loop_SingleWell.json

# %%
# Select simulation
scenario = "open_loop_SingleWell" # NB! Open LOOP
simulation_name = "/data/simulations/sim_" + scenario + ".json"
Data = SimulationData(simulation_name)

# %% [markdown]
# ## Plot Simulation

# %%
fontsize = 10
figsize = 15
plt.rcParams.update({'font.size': fontsize})

cv_fig = PlotPrediction(Data, "Controlled Variables", figsize)
mv_fig = PlotInput(Data, "Manupulated Variables", figsize)

# %% [markdown]
# ### Save figure:

# %%
save_dir = "../fig/plots/"
figname = "open_loop_only_choke"

cv_fig.savefig(save_dir + "cv_" + figname + ".png")
mv_fig.savefig(save_dir + "mv_" + figname + ".png")
